# %% [markdown]
# ---
#
# ## 🚗 **Análise de Dados de Preços de Carros**
#
# **Previsão de preço do carro**
#
# **Projeto**
#
# Este conjunto de dados contém 10.000 entradas criadas com o objetivo de prever os preços dos carros. Cada linha representa informações sobre um carro e seu preço. As descrições das colunas são as seguintes:
#
# ---

# %% [markdown]
# ---
#
# ## **Conjunto de dados:**
#
# **Marca:** Especifica a marca do carro (por exemplo, Toyota, BMW, Ford).
# **Valores de exemplo:** "Toyota", "BMW", "Mercedes".
#
# **Modelo:** Especifica o modelo do carro (por exemplo, Corolla, Focus, X5).
# **Valores de exemplo:** "Corola", "Foco", "X5".
#
# **Ano:** O ano de produção do carro. Os anos mais recentes geralmente indicam preços mais altos.
# **Valores de exemplo:** 2005, 2018, 2023.
#
# **Engine_Size:** Especifica o tamanho do motor em litros (L). Motores maiores geralmente se correlacionam com preços mais altos.
# **Valores de exemplo:** 1.6, 2.0, 3.5.
#
# **Fuel_Type:** indica o tipo de combustível utilizado pelo carro:
# **Gasolina:** Carros movidos a gasolina.
# **Diesel:** Carros movidos a óleo diesel.
# **Híbrido:** Carros que usam combustível e eletricidade.
# **Elétrico:** Carros totalmente elétricos.
#
# **Transmissão:** O tipo de transmissão no carro:
# **Manual:** Transmissão manual.
# **Automático:** Transmissão automática.
# **Semi-Automático:** Transmissão semi-automática.
#
# **Quilometragem:** A distância total percorrida pelo carro, medida em quilômetros. Quilometragem mais baixa geralmente indica um preço mais alto.
# **Valores de exemplo:** 15.000, 75.000, 230.000.
#
# **Portas:** O número de portas no carro. Geralmente 2, 3, 4 ou 5 portas.
# Valores de exemplo: 2, 3, 4, 5.
#
# **Owner_Count:** O número de proprietários anteriores do carro. Menos proprietários geralmente indicam um preço mais alto.
# Valores de exemplo: 1, 2, 3, 4.
#
# **Preço:** O preço de venda estimado do carro. É calculado com base em vários fatores, como ano de produção, tamanho do motor, quilometragem, tipo de combustível e transmissão.
# Valores de exemplo: 5.000, 15.000, 30.000.
#
#
# ## **Origem dos Dados**
# Este dataset foi disponibilizado por Tech no Kaggle e está licenciado em Other:
#
# > Tech, Airplane Price Dataset.
# > Disponível em: [Kaggle Dataset Link](https://www.kaggle.com/datasets/asinow/car-price-dataset/data)
#
# **Objetivo deste projeto é para treinamento e colocar minhas habilidades em prática. Também irei incluí-lo em meu portfólio e assim poder mostrar minhas habilidades e conquistar futuros projetos e clientes na área de Análise e Ciência de Dados com Python.**
#
# ---

# %% [markdown]
# ## Passos do Projeto ##
#
# Passo 1 - Importar o DataFrame
#
# Passo 2 - Analisar o DataFrame
#
# Passo 3 - Correção do DataFrame (Limpeza, organização e modelagem)
#
# Passo 4 - Análise de Dados (analisar as principais variáveis que afetam o preço do carro)
#
# Passo 5 - Visualização de Dados (visualizar e extrair insights que afetam os preços dos carros)
#
#
# ---

# %% [markdown]
# **Passo 1 - Importar o DataFrame**
#
# ---

# %%
# Importando as bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Importando o dataset
df_carro = pd.read_csv("car_price.csv", sep=",")

# Verificando o dataframe
display(df_carro)
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
# Traduzir colunas para português
traducao_colunas = {
    "Brand": "Marca",
    "Model": "Modelo",
    "Year": "Ano",
    "Engine_Size": "Tamanho_Motor",
    "Fuel_Type": "Tipo_Combustivel",
    "Transmission": "Transmissao",
    "Mileage": "Quilometragem",
    "Doors": "Portas",
    "Owner_Count": "Numero_Proprietarios",
    "Price": "Preco"
}

# Renomear as colunas
df_carro = df_carro.rename(columns=traducao_colunas)

display(df_carro)
# Out:
#            Marca    Modelo   Ano  Tamanho_Motor Tipo_Combustivel  \
# 0            Kia       Rio  2020            4.2           Diesel
# 1      Chevrolet    Malibu  2012            2.0           Hybrid
# 2       Mercedes       GLA  2020            4.2           Diesel
# 3           Audi        Q5  2023            2.0         Electric
# 4     Volkswagen      Golf  2003            2.6           Hybrid
# ...          ...       ...   ...            ...              ...
# 9995         Kia    Optima  2004            3.7           Diesel
# 9996   Chevrolet    Impala  2002            1.4         Electric
# 9997         BMW  3 Series  2010            3.0           Petrol
# 9998        Ford  Explorer  2002            1.4           Hybrid
# 9999  Volkswagen    Tiguan  2001            2.1           Diesel
#
#          Transmissao  Quilometragem  Portas  Numero_Proprietarios  Preco
# 0             Manual         289944       3                     5   8501
# ...

# %% [markdown]
# ---
#
# **Passo 2 - Analisar o DataFrame**
#
# ---

# %%
# Usando shape para conferir as dimensões do dataframe
df_carro.shape
# Out:
# (10000, 10)

# %%
# Visualizando as informações do dataframe com info
df_carro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Marca                 10000 non-null  object
#  1   Modelo                10000 non-null  object
#  2   Ano                   10000 non-null  int64
#  3   Tamanho_Motor         10000 non-null  float64
#  4   Tipo_Combustivel      10000 non-null  object
#  5   Transmissao           10000 non-null  object
#  6   Quilometragem         10000 non-null  int64
#  7   Portas                10000 non-null  int64
#  8   Numero_Proprietarios  10000 non-null  int64
#  9   Preco                 10000 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 781.4+ KB

# %%
# Conferindo os tipos de dados utilizados no dataframe com dtypes
df_carro.dtypes
# Out:
# Marca                    object
# Modelo                   object
# Ano                       int64
# Tamanho_Motor           float64
# Tipo_Combustivel         object
# Transmissao              object
# Quilometragem             int64
# Portas                    int64
# Numero_Proprietarios      int64
# Preco                     int64
# dtype: object

# %%
# Verificar se existe valores ausentes no dataframe
df_carro.isna().sum()
# Out:
# Marca                   0
# Modelo                  0
# Ano                     0
# Tamanho_Motor           0
# Tipo_Combustivel        0
# Transmissao             0
# Quilometragem           0
# Portas                  0
# Numero_Proprietarios    0
# Preco                   0
# dtype: int64

# %%
# Verificar se existe valores duplicados no dataframe
df_carro.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Fazer uma análise descritiva do dataframe
df_carro.describe()
# Out:
#                 Ano  Tamanho_Motor  Quilometragem        Portas  \
# count  10000.000000   10000.000000   10000.000000  10000.000000
# mean    2011.543700       3.000560  149239.111800      3.497100
# std        6.897699       1.149324   86322.348957      1.110097
# min     2000.000000       1.000000      25.000000      2.000000
# 25%     2006.000000       2.000000   74649.250000      3.000000
# 50%     2012.000000       3.000000  149587.000000      3.000000
# 75%     2017.000000       4.000000  223577.500000      4.000000
# max     2023.000000       5.000000  299947.000000      5.000000
#
#        Numero_Proprietarios        Preco
# count          10000.000000  10000.00000
# mean               2.991100   8852.96440
# std                1.422682   3112.59681
# min                1.000000   2000.00000
# 25%                2.000000   6646.00000
# 50%                3.000000   8858.50000
# 75%                4.000000  11086.50000
# max                5.000000  18301.00000

# %%
# Verificar quais os tipos de valores estão descritos nas colunas Tipo_Combustivel e Transmissao

# Agrupar a coluna Tipo_Combustivel
coluna_tipo_combustivel = df_carro.groupby("Tipo_Combustivel").size()
display(coluna_tipo_combustivel)

# Agrupar a coluna Transmissao
coluna_transmissao = df_carro.groupby("Transmissao").size()
display(coluna_transmissao)
# Out:
# Tipo_Combustivel
# Diesel      2512
# Electric    2625
# Hybrid      2453
# Petrol      2410
# dtype: int64
# Transmissao
# Automatic         3317
# Manual            3372
# Semi-Automatic    3311
# dtype: int64

# %% [markdown]
# Com o dataframe verificado, constatou-se que existe 10.000 registros e 10 colunas no dataframe. Não há colunas com valores nulos ou vazios e nem registros duplicados. Foi feito também um agrupamento das colunas **Tipo_Combustivel** e **Transmissao** para verificar quais os tipos de valores com as quais estas colunas são preenchidas.
#
# Feita a análise do dataframe e não tendo encontrado erros ou problemas que possam afetar a análise dos dados, podemos passar para o passo 3 para somente alterar os valores dos registros das duas colunas de texto para português.

# %% [markdown]
# ---
#
# **Passo 3 - Correção do DataFrame (Limpeza, organização e modelagem)**
#
# ---

# %%
# Função para substituir os valores das colunas Tipo_Combustivel e Transmissao de texto 
# para números e vice-versa
def codificar():
    if (df_carro["Tipo_Combustivel"].dtypes == object) and (df_carro["Transmissao"].dtypes == object):
        # Codificar de texto para número
        df_carro["Tipo_Combustivel"] = df_carro["Tipo_Combustivel"].replace({
            "Diesel": 0,
            "Electric": 1,
            "Hybrid": 2,
            "Petrol": 3                         
        })
        
        df_carro["Transmissao"] = df_carro["Transmissao"].replace({
            "Automatic": 0,
            "Manual": 1,
            "Semi-Automatic": 2
        })
    else:
        # Cofificar de número para texto
        df_carro["Tipo_Combustivel"] = df_carro["Tipo_Combustivel"].replace({
            0: "Diesel",
            1: "Electric",
            2: "Hybrid",
            3: "Petrol"                          
        })
        
        df_carro["Transmissao"] = df_carro["Transmissao"].replace({
            0: "Automatic",
            1: "Manual",
            2: "Semi-Automatic"
        })

# %%
# Altera tipo da coluna Preco para float
df_carro[["Preco"]] = df_carro[["Preco"]].astype(float)

display(df_carro.dtypes)

display(df_carro)
# Out:
# Marca                    object
# Modelo                   object
# Ano                       int64
# Tamanho_Motor           float64
# Tipo_Combustivel         object
# Transmissao              object
# Quilometragem             int64
# Portas                    int64
# Numero_Proprietarios      int64
# Preco                   float64
# dtype: object
#            Marca    Modelo   Ano  Tamanho_Motor Tipo_Combustivel  \
# 0            Kia       Rio  2020            4.2           Diesel
# 1      Chevrolet    Malibu  2012            2.0           Hybrid
# 2       Mercedes       GLA  2020            4.2           Diesel
# 3           Audi        Q5  2023            2.0         Electric
# 4     Volkswagen      Golf  2003            2.6           Hybrid
# ...          ...       ...   ...            ...              ...
# 9995         Kia    Optima  2004            3.7           Diesel
# 9996   Chevrolet    Impala  2002            1.4         Electric
# ...

# %% [markdown]
# Dataframe corrigido e remodelado.

# %% [markdown]
# ---
#
# **Passo 4 - Análise de Dados**
#
# ---

# %%
# Codificar colunas de texto para número
codificar()

# Fazer uma correlação entre os dados e a variável alvo (Preco)
df_carro.corr(numeric_only=True).abs()[['Preco']].round(3)
# Out:
# C:\Users\robso\AppData\Local\Temp\ipykernel_8600\1718884187.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_carro["Tipo_Combustivel"] = df_carro["Tipo_Combustivel"].replace({
# C:\Users\robso\AppData\Local\Temp\ipykernel_8600\1718884187.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_carro["Transmissao"] = df_carro["Transmissao"].replace({
#                       Preco
# Ano                   0.663
# Tamanho_Motor         0.357
# Tipo_Combustivel      0.037
# Transmissao           0.219
# ...

# %% [markdown]
#  Caracteríticas que mais influenciam o preço segundo a correlação:
#
# O **Ano**, a **Quilometragem** e o **Tamanho_Motor**: são as colunas mais próximas da Coluna Preco, sendo assim, as que mais impactam no preço final carro.
#
# Não menos importante, a **Transmissao** tem uma pequena influencia no preço do carro.
#
# Agora que sabemos quais são as colunas que influenciam o preço final, vamos agrupá-las por preço e analisar como elas impactam no preço final.
#
# ---

# %% [markdown]
# Agrupar as variáveis encontradas na correlação com a variável Preco

# %%
# Agrupar a coluna Preco com as colunas características encontradas na correlação

# Codificar colunas de número para textos
codificar()

# Agrupar pelo ano do carro
ano_carro = df_carro.groupby("Ano")["Preco"].mean().round(2)
display(ano_carro)

# Agrupar pela quilometragem do carro
quilometragem_carro = df_carro.groupby("Quilometragem")["Preco"].mean().round(2)
display(quilometragem_carro)

# Agrupar pelo tamanho do motor
tamanho_motor = df_carro.groupby("Tamanho_Motor")["Preco"].mean().round(2)
display(tamanho_motor)

# Agrupar pelo tipo de transmissão do carro
transmissao_tipo = df_carro.groupby("Transmissao")["Modelo"].count()
display(transmissao_tipo)

# Agrupar pelo tipo de combustível do carro
tipo_combustivel = df_carro.groupby("Tipo_Combustivel")["Modelo"].count()
display(tipo_combustivel)

# Agrupar pelo número de portas do carro
num_portas = df_carro.groupby("Portas")["Modelo"].count()
display(num_portas)

# Agrupar pelo preço médio da marca e modelo do carro
modelo_carro = df_carro.groupby(["Marca", "Modelo"])["Preco"].mean().round(2).reset_index()
display(modelo_carro)
# Out:
# Ano
# 2000     5393.74
# 2001     5904.06
# 2002     5956.75
# 2003     6225.83
# 2004     6330.73
# 2005     6943.04
# 2006     7249.96
# 2007     7632.51
# 2008     7728.42
# 2009     8083.92
# 2010     8503.42
# 2011     8622.86
# 2012     9011.45
# 2013     9114.21
# 2014     9587.46
# 2015     9896.77
# 2016    10177.60
# 2017    10343.76
# 2018    10939.19
# 2019    11132.72
# 2020    11495.28
# 2021    11637.81
# 2022    12067.69
# 2023    12169.47
# Name: Preco, dtype: float64
# Quilometragem
# 25         9499.0
# 74         8998.0
# 88        10298.0
# 178       13196.0
# 184       13096.0
#            ...
# 299714     4805.0
# 299754     7204.0
# 299818     6303.0
# 299872     7402.0
# 299947     7701.0
# Name: Preco, Length: 9854, dtype: float64
# Tamanho_Motor
# 1.0     6785.75
# 1.1     6920.20
# 1.2     6939.92
# 1.3     7265.59
# 1.4     7313.31
# 1.5     7411.48
# 1.6     7823.48
# 1.7     7303.82
# 1.8     7671.15
# 1.9     7924.97
# 2.0     7727.74
# ...

# %% [markdown]
# Como nos mostra os agrupamentos, os preços variam de acordo com a configuração do carro.

# %%
# Análise descritiva dos modelos de carros

# Agrupar pelo preço médio, mínimo, máximo e quantidade de carros por marca e modelo
marca_modelo_preco = df_carro.groupby(["Marca", "Modelo"])[["Preco"]].agg(["mean", "min", "max", "count"]).reset_index()

# Configuração das colunas
marca_modelo_preco.columns = ["Marca", "Modelo", "Preco_Medio", "Preco_Minimo", "Preco_Maximo", "Quantidade"]

# Visualizar os dados
display(marca_modelo_preco.round(2))
# Out:
#          Marca    Modelo  Preco_Medio  Preco_Minimo  Preco_Maximo  Quantidade
# 0         Audi        A3      8912.32        2000.0       18255.0         338
# 1         Audi        A4      8919.96        2374.0       16619.0         350
# 2         Audi        Q5      8955.26        2000.0       16734.0         350
# 3          BMW  3 Series      8854.75        2000.0       17134.0         335
# 4          BMW  5 Series      8669.22        2000.0       17386.0         353
# 5          BMW        X5      8581.31        2000.0       16544.0         311
# 6    Chevrolet   Equinox      9156.32        2000.0       17054.0         315
# 7    Chevrolet    Impala      9001.12        2000.0       17072.0         355
# 8    Chevrolet    Malibu      8898.18        2000.0       17661.0         333
# 9         Ford  Explorer      8804.90        2000.0       18017.0         334
# 10        Ford    Fiesta      8971.08        2000.0       16705.0         363
# ...

# %% [markdown]
# ---
#
# **Passo 5 - Visualização de Dados**
#
# ---

# %% [markdown]
# Criar um gráfico de mapa de calor para observar a correlação com mais eficácia.

# %%
# Gráfico de mapa de calor para visualização da correlação entre os dados

# Codificar colunas de texto para números
codificar()

# Configuração da figura
plt.figure(figsize=(13, 6))

# Plotar o gráfico de mapa de calor
sns.heatmap(df_carro.corr(numeric_only=True), annot=True, cmap='coolwarm')

plt.title('Correlação entre o Preço dos Carros')
plt.show()
# Out:
# C:\Users\robso\AppData\Local\Temp\ipykernel_8600\1718884187.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_carro["Tipo_Combustivel"] = df_carro["Tipo_Combustivel"].replace({
# C:\Users\robso\AppData\Local\Temp\ipykernel_8600\1718884187.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_carro["Transmissao"] = df_carro["Transmissao"].replace({

# %% [markdown]
# O gráfico de mapa de calor confirma a correlação da análise.

# %% [markdown]
# ---
#
# Criar gráficos de linha para visualização da relação entre as variáveis e a coluna Preco
#
# ---

# %%
# Visualização e Análise Gráfica da relação entre variáveis e a coluna Preço

# Codificar colunas de números para texto
codificar()

# Criação dos Gráficos
for i, coluna in enumerate(df_carro.columns):
    sns.set_theme(style='whitegrid')
    # Configuração da figura
    plt.figure(figsize=(13, 6))

    # Plotar Gráficos de Linha - Variação das colunas em relação ao Preco
    sns.lineplot(data=df_carro, x=coluna, y="Preco", linestyle = '-', linewidth = 2, marker = 's', color="green")
    plt.title('Relação Entre o Preço dos Carros - ' + coluna)
    if i == 1:
      plt.xticks(rotation=45)
    else:
       plt.xticks(rotation=0)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---
# Gráficos para visualizar a relação das especificações do carro

# %%
# Visualização e Análise Gráfica - Gráficos de Pizza 

# Configuração da figura
plt.figure(figsize=(13, 7))

# Plotar o gráfico de pizza - Número de carros por tipo de transmissão
plt.subplot(1, 2, 1)
plt.pie(transmissao_tipo, labels=transmissao_tipo.index, autopct='%1.1f%%', startangle=140)
plt.title('Número de Carros por Tipo de Transmissão')
plt.axis('equal')

# Plotar o gráfico de pizza - Número de carros por tipo de combustível
plt.subplot(1, 2, 2)
plt.pie(tipo_combustivel, labels=tipo_combustivel.index, autopct='%1.1f%%', startangle=140)
plt.title('Número de Carros por Tipo de Combustível')
plt.axis('equal')

plt.tight_layout()
plt.show()

# %%
# Plotando o gráfico de barra e pizza

# Configuração da figura
plt.figure(figsize=(15, 8))

# Plotar o gráfico de barra - Preço médio dos modelos de carros por marca
plt.subplot(1, 2, 1)
sns.barplot(data=modelo_carro, x='Marca', y='Preco', hue='Modelo', dodge=False)
plt.title('Preço dos Modelos de Carros por Marca')
plt.xlabel('Marca')
plt.ylabel('Preço')
plt.legend(title='Modelo', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)

# Plotar o gráfico de barra - Número de portas dos carros
plt.subplot(1, 2, 2)
plt.pie(num_portas, labels=num_portas.index, autopct="%1.1f%%", startangle=140)
plt.title("Número de Portas dos Carros")
plt.axis("equal")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# **Conclusão da Visualização dos dados**
#
# 1 - As marcas Chevrolet, Mercedes, Audi e Volkswagem são as mais valorizadas. Kia, Toyota, Hyundai e Ford se mantém na média. Honda e BMW são os menos valorizados. Obs.: Os mais valorizados exlcuindo a Chevrole que é de procedência norte-americana, as outras todas são de procedência alemã. Nos preços médios as procedências são variadas, com Kia e Hyundai da Coreia, Toyota do Japão e Ford dos USA. Já nos de menor preço estão Honda do Japão e BMW da alemanha.
#
# 2 - O preço sofre bastante variação em relação aos modelos, isso decorre da relção entre as outras variáveis em relação ao preço final.
#
# 3 - Em relção ao ano dos carros é natural que seus valores tende a ser menores à medida que os mesmos vão ficando mais velhos devido a depreciação do carro.
#
# 4 - O tamanho do motor é um fator que influencia bastante no preço, quanto maior o motor, mais potente ele é, impacatanto no preço final do carro.
#
# 5 - Os carros elétricos são os de maior valor, provavelmente devido a tecnologia mais avançada.
#
# 6 - A transmissão automática também impacta no preço do carro, devido a complexidade e auto custo de manutenção desse sistema.
#
# 7 - Carros com alta kilometragem naturalmete sofrem maiores depreciações.
#
# 8 - O número de portas não influencia muito no preço, pois a maioria dos carros possuem de 3 à 4 portas.
#
# 9 - O número de propritários também não tem influência no preço com uma variação equilibrada em relação ao número de proprietários.
#
# ---
#
# ## **Conclusão Final** ##
#
# De acordo com as análises e visualizações, chegamos a conclusão de que os fatores tecnológicos como (tipo de transmissão, tipo de combustível e o tamanho do motor) são os fatores que mais impactam o preço final dos carros. As marcas alemãs são as mais valorizadas. A menor quilometragem percorrida e o ano de fabricação também são fatores que influenciam bastante no preço final do carro.
#
# ---

# %% [markdown]
# ---
#
# ## 🚗 **Análise de Dados de Preços de Carros**
#
# **Previsão de preço do carro**
#
# ### **Inteligência Artificial e Previsões**:
# **Concluída uma análise aprofundada nos dados e com insights valiosos extraídos, vamos aproveitar esses insights e aplicá-los em um modelo de Inteligência Artificial IA, que consiga ler essas novas informações e dizer automaticamente a previsão de preço dos carros**
#
# Com o dataframe analisado e com base na análise, criar o modelo de Inteligência Artificial e Previsões.
#
# ---

# %% [markdown]
# ## Passos do Projeto ##
#
# Passo 1 - Preparar o dataframe para a Inteligência Artificial
#
# Passo 2 - Treinar a Inteligência Artificial
#
# Passo 3 - Escolher o melhor modelo
#
# Passo 4 - Usar o melhor modelo
#
# ---

# %%
# Importando as bibliotecas necessárias
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Criando um novo dataframe para a IA, a partir do dataframe original
df_carro_ia = df_carro

display(df_carro_ia)
# Out:
#            Marca    Modelo   Ano  Tamanho_Motor Tipo_Combustivel  \
# 0            Kia       Rio  2020            4.2           Diesel
# 1      Chevrolet    Malibu  2012            2.0           Hybrid
# 2       Mercedes       GLA  2020            4.2           Diesel
# 3           Audi        Q5  2023            2.0         Electric
# 4     Volkswagen      Golf  2003            2.6           Hybrid
# ...          ...       ...   ...            ...              ...
# 9995         Kia    Optima  2004            3.7           Diesel
# 9996   Chevrolet    Impala  2002            1.4         Electric
# 9997         BMW  3 Series  2010            3.0           Petrol
# 9998        Ford  Explorer  2002            1.4           Hybrid
# 9999  Volkswagen    Tiguan  2001            2.1           Diesel
#
#          Transmissao  Quilometragem  Portas  Numero_Proprietarios    Preco
# 0             Manual         289944       3                     5   8501.0
# ...

# %% [markdown]
# ---
#
# **Passo 1 - Preparar o dataframe para a Inteligência Artifical**
#
# ---

# %%
# Codificar as colunas para tipo numérico para a Inteligência Artificial

# Codificar coluna Marca
codificador_marca = LabelEncoder()
df_carro_ia["Marca"] = codificador_marca.fit_transform(df_carro_ia["Marca"])

# Codificar coluna Tipo Modelo
codificador_modelo = LabelEncoder()
df_carro_ia["Modelo"] = codificador_modelo.fit_transform(df_carro_ia["Modelo"])

# Codificar coluna Tipo_Combustivel
codificador_combustivel = LabelEncoder()
df_carro_ia["Tipo_Combustivel"] = codificador_combustivel.fit_transform(df_carro_ia["Tipo_Combustivel"])

# Codificar coluna Transmissao
codificador_transmissao = LabelEncoder()
df_carro_ia["Transmissao"] = codificador_transmissao.fit_transform(df_carro_ia["Transmissao"])

df_carro_ia.info()

display(df_carro_ia)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Marca                 10000 non-null  int64
#  1   Modelo                10000 non-null  int64
#  2   Ano                   10000 non-null  int64
#  3   Tamanho_Motor         10000 non-null  float64
#  4   Tipo_Combustivel      10000 non-null  int64
#  5   Transmissao           10000 non-null  int64
#  6   Quilometragem         10000 non-null  int64
#  7   Portas                10000 non-null  int64
#  8   Numero_Proprietarios  10000 non-null  int64
#  9   Preco                 10000 non-null  float64
# dtypes: float64(2), int64(8)
# memory usage: 781.4 KB
#       Marca  Modelo   Ano  Tamanho_Motor  Tipo_Combustivel  Transmissao  \
# 0         6      24  2020            4.2                 0            1
# ...

# %%
# Preparar o dataframe para o treino

# y é a coluna do dataframe a ser prevista
y = df_carro_ia["Preco"]

# x são as colunas do dataframe que serão usadas para a previsão
x = df_carro_ia.drop(columns=["Preco"])

# Separar os dados de treino e os dados de teste
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ---
#
# **Passo 2 - Treinar a Inteligência Artificial**
#
# ---

# %%
# Criar o medelo -> Prever os Preços em USD

# Arvore de Decisão -> RandonForest
# Nearest Neighbors -> KNN -> KNeighbors
# Regressão Linear -> RLN -> LinearRegression

# Cria a IA
modelo_arvore_decisao = RandomForestRegressor()
modelo_knn = KNeighborsRegressor()
modelo_rln = LinearRegression()

# Treinar a IA
modelo_arvore_decisao.fit(x_treino, y_treino)
modelo_knn.fit(x_treino, y_treino)
modelo_rln.fit(x_treino, y_treino)
# Out:
# LinearRegression()

# %% [markdown]
# ---
#
# **Passo 3 - Escolher o melhor modelo**
#
# ---

# %%
# Testar os modelos

# Prever valores de teste usando os modelos de Regressão Linear
previsao_arvore_decisao = modelo_arvore_decisao.predict(x_teste)
previsao_knn = modelo_knn.predict(x_teste)
previsao_rln = modelo_rln.predict(x_teste)

# Calcular e exibir o Erro Absoluto Médio (MAE) dos modelos
print(f'MAE Árvore de Decisão: {mean_absolute_error(y_teste, previsao_arvore_decisao):,.2f}')
print(f'MAE KNN: {mean_absolute_error(y_teste, previsao_knn):,.2f}')
print(f'MAE Regressão Linear: {mean_absolute_error(y_teste, previsao_rln):,.2f}')

# Calcular e exibir o Erro Quadrático Médio (MSE) dos modelos
print(f'MSE Árvore de Decisão: {mean_squared_error(y_teste, previsao_arvore_decisao):,.2f}')
print(f'MSE KNN: {mean_squared_error(y_teste, previsao_knn):,.2f}')
print(f'MSE Regressão Linear: {mean_squared_error(y_teste, previsao_rln):,.2f}')

# Calcular e exibir a acurácia dos modelos
display(modelo_arvore_decisao.score(x_teste, y_teste) * 100)
display(modelo_knn.score(x_teste, y_teste) * 100)
display(modelo_rln.score(x_teste, y_teste) * 100)
# Out:
# MAE Árvore de Decisão: 375.18
# MAE KNN: 2,272.48
# MAE Regressão Linear: 793.48
# MSE Árvore de Decisão: 222,381.00
# MSE KNN: 7,740,485.80
# MSE Regressão Linear: 818,588.25
# 97.57960869015123
# 15.75267403370686
# 91.09049829961214

# %% [markdown]
# O melhor modelo é o Arvore de Decisão.

# %% [markdown]
# ---
#
# **Passo 4 - Usar melhor modelo**
#
# ---

# %%
# Usar o melhor modelo -> Modelo Arvore de Decisão

#Importar os novos aviões para previsão
df_novos_dados = pd.read_csv("car_price_novos.csv")

# Codificar o novo dataframe

# Codificar coluna Marca
codificador_marca = LabelEncoder()
df_novos_dados["Marca"] = codificador_marca.fit_transform(df_novos_dados["Marca"])

# Codificar coluna Tipo Modelo
codificador_modelo = LabelEncoder()
df_novos_dados["Modelo"] = codificador_modelo.fit_transform(df_novos_dados["Modelo"])

# Codificar coluna Tipo_Combustivel
codificador_combustivel = LabelEncoder()
df_novos_dados["Tipo_Combustivel"] = codificador_combustivel.fit_transform(df_novos_dados["Tipo_Combustivel"])

# Codificar coluna Transmissao
codificador_transmissao = LabelEncoder()
df_novos_dados["Transmissao"] = codificador_transmissao.fit_transform(df_novos_dados["Transmissao"])

# Visualizar o dataframe
display(df_novos_dados)

# Fazer a previsão através do modelo árvore de decisão
nova_previsao = modelo_arvore_decisao.predict(df_novos_dados)

# Exibir a previsão
display(nova_previsao)
# Out:
#     Marca  Modelo   Ano  Tamanho_Motor  Tipo_Combustivel  Transmissao  \
# 0       6      14  2001            4.7                 1            2
# 1       8      13  2005            3.1                 3            1
# 2       9       9  2007            3.2                 0            0
# 3       5       4  2017            2.9                 1            0
# 4       2       5  2018            1.8                 2            0
# 5       3       6  2006            2.8                 2            1
# 6       1       0  2020            4.7                 1            2
# 7       4       2  2015            2.6                 1            2
# 8       7       8  2007            2.3                 1            1
# 9       7       3  2011            1.8                 0            2
# 10      2      10  2011            4.0                 2            0
# 11      3       7  2003            3.2                 3            2
# ...

# %% [markdown]
# ---
#
# **Criar o arquivo com as novas previsões**
#
# ---

# %%
# Reverter a codificação de volta para os rótulos originais
df_novos_dados["Marca"] = codificador_marca.inverse_transform(df_novos_dados["Marca"])
df_novos_dados["Modelo"] = codificador_modelo.inverse_transform(df_novos_dados["Modelo"])
df_novos_dados["Tipo_Combustivel"] = codificador_combustivel.inverse_transform(df_novos_dados["Tipo_Combustivel"])
df_novos_dados["Transmissao"] = codificador_transmissao.inverse_transform(df_novos_dados["Transmissao"])

# Criar um arquivo de previsão
output = pd.DataFrame({
    "Marca": df_novos_dados["Marca"],
    "Modelo": df_novos_dados["Modelo"],
    "Ano": df_novos_dados["Ano"],
    "Tamanho_Motor": df_novos_dados["Tamanho_Motor"],
    "Tipo_Combustivel": df_novos_dados["Tipo_Combustivel"],
    "Transmissao": df_novos_dados["Transmissao"],
    "Quilometragem": df_novos_dados["Quilometragem"],
    "Portas": df_novos_dados["Portas"],
    "Numero_Proprietarios": df_novos_dados["Numero_Proprietarios"],
    "Preco": nova_previsao
})
output.to_csv("car_forecast.csv", index=False)

print("Your forecast was successfully saved!")

# Ler o arquivo de previsão
df_previsao = pd.read_csv("car_forecast.csv")

# Visualizar o arquivo de previsão
display(df_previsao)
# Out:
# Your forecast was successfully saved!
#          Marca    Modelo   Ano  Tamanho_Motor Tipo_Combustivel  \
# 0          Kia  Sportage  2001            4.7         Electric
# 1       Toyota      RAV4  2005            3.1           Petrol
# 2   Volkswagen      Golf  2007            3.2           Diesel
# 3      Hyundai   Elantra  2017            2.9         Electric
# 4    Chevrolet   Equinox  2018            1.8           Hybrid
# 5         Ford  Explorer  2006            2.8           Hybrid
# 6          BMW  3 Series  2020            4.7         Electric
# 7        Honda     Civic  2015            2.6         Electric
# 8     Mercedes       GLA  2007            2.3         Electric
# 9     Mercedes   E-Class  2011            1.8           Diesel
# 10   Chevrolet    Impala  2011            4.0           Hybrid
# 11        Ford     Focus  2003            3.2           Petrol
# 12  Volkswagen    Tiguan  2006            4.4           Petrol
# ...

# %% [markdown]
# ---

# %%
# Características mais importantes para definir os preços

colunas = list(x_teste.columns)
importancia = pd.DataFrame(index=colunas, data=modelo_arvore_decisao.feature_importances_)
importancia = importancia * 100
print(importancia)
# Out:
#                               0
# Marca                  0.392413
# Modelo                 0.520587
# Ano                   44.040227
# Tamanho_Motor         13.930724
# Tipo_Combustivel       3.918576
# Transmissao            4.909763
# Quilometragem         31.756499
# Portas                 0.247548
# Numero_Proprietarios   0.283662

# %% [markdown]
# O modelo de IA também nos mostra as características mais importantes para definir os preços dos carros.
#
# Na análise acima é possível notar que as variáveis **Ano** e **Quilometragem** são as características mais importantes, como mostrado na Análise dos Dados e irão continuar a definir as próximas análises, baseados em dados futuros e também o **Tamanho do Motor**, os tipos de **Transmissão** e de **Combustível** ajudam a definir o preço final dos carros.
#
# ---
#
# **📈 Análise de Dados e Machine Learning**
#
# **© 2025 - by Robson Silva - Programador Python e Analista de Dados.**
#
# ---
